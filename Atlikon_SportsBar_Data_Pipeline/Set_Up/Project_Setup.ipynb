# %%
# %sql
CREATE CATALOG IF NOT EXISTS sportats;
USE CATALOG sportats;

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS sportats.bronze;
CREATE SCHEMA IF NOT EXISTS sportats.silver;
CREATE SCHEMA IF NOT EXISTS sportats.gold;
