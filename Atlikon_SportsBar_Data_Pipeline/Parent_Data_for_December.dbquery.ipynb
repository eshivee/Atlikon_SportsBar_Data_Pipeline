-- %%
COPY INTO sportats.gold.fact_orders
FROM(
  SELECT 
  CAST(date AS DATE) AS date,
  customer_code,
  product_code,
  CAST(sold_quantity AS BIGINT) as sold_quantity
  FROM '/Volumes/sportats/gold/fmcg_parent_facts_table/fact_orders.csv'
)
FILEFORMAT = CSV
FORMAT_OPTIONS('header' = 'true')
